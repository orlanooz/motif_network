# %%
from centrality_analysis import run

df = run(
    graphml_path="../dataset/all_materials_network.graphml",
    output_dir="centrality_outputs",
    partition="material",
    save_csv=True,
    make_plots=False
)

df.head()
