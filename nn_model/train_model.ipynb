# %%
from train_mat_prop import run_grid

best = run_grid(
    target="bandgap",  # "fe" or "bandgap"
    emb_file="/home/anoj/work/network/bine/data/all_materials/vectors_u4n.dat_iter300.dat",
    features_pkl="/home/anoj/work/network/data/features_all_materials.pkl",
    save_dir="./data/runs",
    epochs=10,
    batch_sizes=[64, 32],
    lrs=[0.005, 0.001, 0.0001],
    hidden_dim=32,
    split=(0.8, 0.1, 0.1),
    seed=7,
    num_workers=0,
    shuffle_train=True,
    weight_decay=0.0,
    save_best_metric="val_mae",
    fe_min=-8.0,
    bg_min=0.0,
    bg_max=None,
    plots=True,
    device=None,
    parity_range=None
)

best["paths"]["best_ckpt"]
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ...
